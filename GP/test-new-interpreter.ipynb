# %%
from venture import shortcuts


import numpy as np
import numpy.linalg as la
import numpy.random as npr
import scipy.spatial.distance as spdist

from venture.lite.function import VentureFunction
from venture.lite.sp import SPType
import venture.lite.value as v
import venture.value.dicts as d
from venture.lite.builtin import typed_nr

import pylab as pl
import seaborn
from IPython.display import display, Math, Latex

import timeit
import itertools

import sys
sys.path.append('../SPs/')
from grammar5 import Grammar
from kernel_interpreter import GrammarInterpreter
import gp_der as gp_with_derivatives
from covFunctions import *


figlength = 16
figheigth = 8
xa = 0
xb = 10

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['array']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
constantType = SPType([v.AnyType()], v.NumberType())
def makeConstFunc(c):
  return VentureFunction(lambda _: c, sp_type=constantType)
def array(xs):
  return v.VentureArrayUnboxed(np.array(xs),  v.NumberType())
covfunctionType = SPType([v.NumberType(), v.NumberType()], v.NumberType())

# %%
ripl = shortcuts.make_lite_church_prime_ripl()

# %% [markdown]
# #### Zero Mean

# %%
ripl.assume('make_const_func', VentureFunction(makeConstFunc, [v.NumberType()], constantType))
ripl.assume('zero', "(apply_function make_const_func 0)")
# Out:
# <function __main__.<lambda>>

# %% [markdown]
# #### LIN

# %% [markdown]
# ## Hyperparameters

# %%
ripl.assume('make_linear', VentureFunction(makeLinear, [v.NumberType()], v.AnyType("VentureFunction")))
ripl.assume('make_periodic', VentureFunction(makePeriodic, [v.NumberType(), v.NumberType(), v.NumberType()], v.AnyType("VentureFunction")))
# Out:
# <function covFunctions.makePeriodic>

# %% [markdown]
# ### WN

# %%
ripl.assume('make_noise', VentureFunction(makeNoise, [v.NumberType()], v.AnyType("VentureFunction")))
# Out:
# <function covFunctions.makeNoise>

# %% [markdown]
# ## Underlying Ground Truth

# %%
ground_truth = "periodicpluslinear"

# %%
if ground_truth == "periodic":
    ripl.assume('noise','(lambda (x) (normal 0 0.1))')
    ripl.assume('true_function','(lambda ( x)  (sin (* 3 x ))   )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = \sin (3x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.1)'))
    ya = -5 # plotting parameter
    yb =5

# %%
if ground_truth == "linear":
    ripl.assume('noise','(lambda (x) (normal 0 1))')
    ripl.assume('true_function','(lambda ( x)   (* 2 x )   )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = 2 * x  + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,1)'))
    ya = 0 # plotting parameter
    yb =20

# %%
if ground_truth == "periodicpluslinear":
    ripl.assume('noise','(lambda (x) (normal 0 0.7))')
    ripl.assume('true_function','(lambda ( x)   ( + (* 2 x ) (* 2 (sin (* 5 x ))))  )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = 2 * x  + 2 \sin (5 x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.7)'))
    ya = 0 # plotting parameter
    yb =20
# Out:
# $$y = f(x) + \eta_x = 2 * x  + 2 \sin (5 x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.7)$$

# %% [markdown]
# ## Sample Training Data

# %%
n = 30
xtrain = np.random.uniform(0,10,n)
ytrain = np.zeros((xtrain.shape))
for i in range(n): 
     sample_from_y= "( y %f )" % xtrain[i]
     ytrain[i]=ripl.sample(sample_from_y)

# %% [markdown]
# ### For plotting the actual function, we sample from the real thing:

# %%
n = 200
actual_x = np.linspace(0,10,n)
actual_f = np.zeros((actual_x.shape))
for i in range(n): 
     sample_from_f= "( true_function %f )" % actual_x[i]
     actual_f[i]=ripl.sample(sample_from_f)

# %% [markdown]
# #### Resample to see posterior on structure

# %%
start = timeit.timeit()

# %%
ripl.infer("(resample 100)")
# Out:
# []

# %%
ripl.assume('a','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')
ripl.assume('sn','(tag (quote hypers) 2 (uniform_continuous 0.01 3))')
ripl.assume('sf','(mem (lambda (i) (tag (quote hypers) i(uniform_continuous 0.1 2 ))))')
ripl.assume('p','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')
ripl.assume('l','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')

ripl.assume("log_a","(lambda (i) (log (a i)))")
ripl.assume("log_sn","(log sn )")
ripl.assume("log_sf","(lambda (i) (log (sf i)))")
ripl.assume("log_p","(lambda (i) (log (p i)))")
ripl.assume("log_l","(lambda (i) (log (l i)))")
# Out:
# 'unknown spAux'

# %%
ripl.assume('lin', "(apply_function make_linear (log_a 0)  )")
ripl.assume('per', "(apply_function make_periodic (log_l 1) (log_p 1) (log_sf 1) )")
# Out:
# <function covFunctions.f>

# %% [markdown]
# ### make covs in ripl

# %%
ripl.assume('wn', "(apply_function make_noise sn)")
# Out:
# <function covFunctions.f>

# %% [markdown]
# ### GP Structure Prior

# %% [markdown]
# ##### for simplicity, I start with the max amount of kernel per type given

# %%
ripl.assume("max_lin","(array  lin )")
ripl.assume("max_per","(array  per )")
ripl.assume("max_wn","(array wn)")
# Out:
# [<function covFunctions.f>]

# %%
number = 3
simplex = "( simplex  "
total_perms =0
perms = []
for i in range(number):
    perms.append((len(list(itertools.permutations([j for j in range(i+1)])))))
    total_perms+=perms[i]    
simplex = "( simplex  "
for i in range(number):
    simplex+=str(float(perms[i])/total_perms) + " "
    
simplex+=" )"  
print(simplex)
# Out:
# ( simplex  0.111111111111 0.222222222222 0.666666666667  )

# %%
ripl.assume("number_components","(tag (quote complexity) 0 (categorical "+simplex+"))")
# Out:
# 1

# %%
ripl.bind_foreign_sp("gp_grammar", typed_nr(Grammar(), [v.HomogeneousArrayType(v.HomogeneousArrayType(v.AnyType())),v.AnyType()], covfunctionType, min_req_args=0))

# %%
ripl.assume("grammar","(tag (quote grammar) 0 (gp_grammar (array max_lin max_wn max_per) number_components ))")
# Out:
# <function grammar5.<lambda>>

# %% [markdown]
# #### way so that we can visualize posterior:

# %%
ripl.bind_foreign_sp("covfunc_interpreter",typed_nr(GrammarInterpreter(), [v.AnyType()], v.AnyType()))

# %%
ripl.assume("interp","(covfunc_interpreter grammar)")
# Out:
# [1.208560140011202, 2.06007618955499, 0.917489040007444, 0.45537302264347057]
# [1.861285200155402, 1.5116374682078706, -0.13351211045475586, 1.8913156773152198, 2.0746702078119426]
# [0.15822491283973225, 1.7529547843513351, -0.9155183306239103, 0.0710087646877896, 1.1679737947780024]
# [1.5581097360379608, 1.902872103054535, 1.5513216671540326, -1.4760213908006328]
# [1.9778706326762518, 0.08666837833359325, -0.46162430497961743]
# [1.0659718316676168]
# [-2.2664478297921593, 1.191139786567073, 1.3971287189764314, 1.5462289583495707, 0.06583728878584634]
# [1.9656190864751688, 1.2167650094194649, 2.0634201628555284, 0.5637419053492161, 1.0512252803294926]
# [1.4375524416441823, 1.9751763571587067, -1.1633563911375182, 1.645246451721737, 0.2355007698730859]
# [0.26115222985440306, 1.8411249696404408, -0.18260638748208338, 1.5225268368776959]
# [0.9828486545976463, -0.17321402856751872, 0.6112305346896351, 0.14565381786568238]
# [1.8402659847079823, 0.040769848337280694, 0.40123791810738385, 1.7220493419102985, -0.3753925963657598]
# [0.9367721323046866, 1.9187472025425762, -0.2930043120729998, 1.1982902091066134, -0.16090170528834327]
# [0.8900455221656671, 0.8279461608139214, 0.9383300312071408, -0.08227011028052203, 0.5299482907436733]
# [1.5166064087716893, 1.9831233837146458, -0.17613986191016628, 1.6771166288616006, 0.7941517896526558]
# [0.9261176564778356, 1.1634685131584683, -0.36442322723972087, 1.5186037649636177, 1.3296948169240084]
# [1.970552514175487, 2.731571240377397]
# [1.7126927403551087, 1.22535124470464, 1.2046856577900362, 0.5678135979849398, 1.4606099021342012]
# [2.4109317351370345, 1.2443406766457588, 1.7273101323579851, 1.230717510876661, 0.2657834819710141]
# [1.830007872952884, 1.911684089199441, -0.14963233010263324, 2.0397078857177893, 0.6808548233966374]
# [0.3379666429691784, 0.7675128435675045, 1.3780992450893683, 1.6889767897719021, 0.5233866388259094]
# [1.5581322966031752, 1.0404581104117572, -0.2439726839969368, 0.6957412188118453, 1.2069070601442362]
# [1.8836090386291664, 1.5315422537853802, -0.34103930373824537, -0.31722528012157153]
# [-1.123200682985327, 1.7204875258104608, -0.5185717260382465, 0.10258121063227735, 0.9953328056559313]
# [1.4463715394081689, 1.5468353327317939, 1.3638151992092986, 1.4759519889092976, 0.39918115432319323]
# [2.008507151400357, 2.283864607512783, 1.6992843429106184, 1.6660634479302454, 0.40802589097023273]
# [2.0475115729188125, 1.163534116747238, 1.9053268786329296, 0.424567484980982, 2.775972581716755]
# [0.891823708891494, 0.12647385356389573, 1.6935463235773656, 0.2668109748032441, 0.415265191782381]
# [2.577274391886008, 1.8298352670020879, 2.0505197007331186, -0.39388700066517685, 1.4481421236233276]
# [2.039456343544823, 1.7607645195028725, 0.5172071465937811, 1.8171449611137616]
# [1.2408662685132545]
# [1.7804180008916763, 0.27450165639997276, 1.628873892309514, -0.30101828940205105, 1.8441539665254727]
# [0.6226052378820146, 1.1394285352367262, 1.3602460669199496, -1.2074609059703065]
# [1.7993858032317884, 0.952985012728264, -1.2126229577327674, 1.6232784295352474, 1.4563527380187655]
# [1.1740725653679294, 1.7875216149112034, 1.6192277182667765, 0.6197304984161415, 0.5586087376922724]
# [-0.21029630163969243, 1.452210461489771, -1.6353419264114084, 0.31355261627575637, -0.7084958961592317]
# [2.5717094406000425, 1.1553686837970754, 0.5640714692633314, -2.0290831930777005, 0.7162151313442293]
# [1.3700261049086848, 0.7839757503443707, 0.07157523860560361, 0.1778843667703614, 1.669483031080381]
# [1.9437234794266076, 1.1915686372618872, 0.2654532840069235, 1.860920345101852, 0.25125391737322816]
# [0.8942951592928414, 1.9423202001631727, 1.955075695935307, 0.5231285929222255, 1.559378083416662]
# [2.6073479492417473, 1.5610818096808037, 1.6268117452167414, 0.5698349260386406, -0.5354281830313576]
# [1.7526406971849091, 2.23245054520121, 2.006872275967236, 1.1914825237243085, -0.8508964010024783]
# [0.87239945591505, 1.071453334736293, 0.7549709461510946, 0.06026996699734526, 1.6577234279822182]
# [1.3979572790369186, 0.4577649446428799, 0.7149296787464998, 1.6856317399031986, 0.08233863547888998]
# [0.548961743112037, 0.9282342933601176, 0.40822871110777603, 2.2890426168161446, 1.396596752422456]
# [1.2587945287509792, 1.50536257915639, -0.7267039055501668]
# [2.724378663353548, 0.9953133756344902, 0.8805179072830244, 1.9374961585699109, -0.0013574660447616138]
# [0.25246119850271936, 1.697944628624453, -0.3515467628733986, 0.6382662453465757, 1.7309614485751461]
# [1.3561520894759376, 1.1965386983065631, 0.43888771613470007, 1.8459154913610896, 2.218635590376269]
# [0.10788774855068116]
# [0.04866790972417356, 1.2288108414437362, 1.0551835255801487, 1.539137004003028, 0.4491300978620755]
# [0.5259171365926566, 1.607056804813928, 1.0682120963354702, -0.22636472096649807]
# [-0.5621824369495677, 1.3715656347372644, 0.7666591079208098, 0.22361400653575797, 1.308941762626344]
# [2.049423870512209, 0.7099145029719534, 0.30402209813594433, 0.7128477848629527, 1.7741658802690439]
# [0.0004074040237256091, 1.652393889805744, 1.4332865537383548, 0.5886995990742113, 1.2668300717275438]
# [0.12296891991934326]
# [2.511443090011668, 1.3697614418307487, -0.5397580751555519, -1.0461930105644432, 1.6412848532698692]
# [2.0017686262593983, 1.858566216193537, 0.5654504068043342, 1.5447626895814022, 1.8105782826374177]
# [0.92770855512692, 1.4627795879340137, -0.2512202117222189, 0.9728475366754058]
# [1.4757537120276167, 2.111261323235201, 1.0075565223236183, 1.446693954740201, 0.4933037233113561]
# [0.8995934315400672, 1.5361549527803604, 0.008184118840273594, 0.10262800348387137, 1.8837248520933876]
# [0.8585489937412137]
# [2.3475134744967847, 0.5640115635720441, 2.032996811632593, -0.8683963853270296]
# [2.741947686736868, 0.9860418126019814, 1.9395467529309007, 0.5563155158700399, 0.3027275584735579]
# [-0.15076090832065395, 2.2307026583699163]
# [0.7069049973519943, 2.010860132469627]
# [2.043646620639449, 1.6159191115923437, -1.2954896643575897, 0.5000116765065334, 1.3981500536087965]
# [1.4048387205583244, -0.8762107743159149, 0.34948125479520453, 0.24625787381117434, 1.807917612048896]
# [-0.5657700307000013, 1.8291728354860803]
# [1.4889067394279862, 1.8202037313389687, 1.1503654989869903, 0.5993450873928483, 1.5604710410443456]
# [2.033658606632016, 2.029788723724815, -0.4392375547269359, 0.9162413775530709]
# [1.9697452565996783, 1.6404247710087578, 1.0938805171014387, 0.6063361095901748]
# [1.993551773301642, 0.42020685162309795, 1.8791881558586798, -1.038723904557713, -0.9966791488167379]
# [1.8971659315285234, 1.9824531246243398, -1.6571310194744298, 1.8941094795835673, 0.019197456208323964]
# [1.8943556645284938, 2.0091294273641576]
# [1.8473720487368455, 0.8296145954735462, -1.0730193213945367, 2.07300499827201, 2.6247880519608167]
# [0.9559788795245687, 1.658032171367031, 0.6626706503213076, 2.0009361198520415, 1.899212764259656]
# [2.8174504822389883, 0.19273985037570976, 1.5151542634595945, 1.8398658205242666, -0.5789652011721766]
# [-0.034722375933662515, 0.21992165155946317, -0.41173121761611164]
# [1.9110253453593615, 1.4166130610222312, 2.075968706710196, 0.5389322758130027]
# [1.2333548361419107, 1.391429787405497, -0.354558092575698, 1.9472956313538858, 1.6117874004827504]
# [1.5444081348334346, 1.3821141694043848, 1.9284827077506788, -1.0344323951429346]
# [2.0251222829139985, 1.380306328697126, 1.3486594135634997, 0.28371751323201305, 2.4807426971684676]
# [2.008042152198936, 0.161880297259407, 0.20161496373726875, 1.3811143037736655]
# [0.9554176029198611, 1.5186489484194658, 1.6184293037322515, -0.26997649488303693, -0.820912685543715]
# [1.7924009235272174, 1.89048180301505, 1.8400670986631986, 0.4418354987223465, 0.019757649554051904]
# [1.7195874526470296, 1.8440036892437968, -1.1978495604386463]
# [1.600126385178498, 2.624680775097508, 1.6409700272989642, 1.6611054686445499, -1.9670765319609096]
# [2.279821788067554, 1.6667148175809516, 0.6436019635234402, -0.5073243488186223, 0.7000987817105836]
# [0.9747590792254568, -2.298776588582159, 1.4899183161979839, -0.30105096350958777]
# [0.8242267559057884, 0.8992362475237415, 0.7660722634055674, 0.469315102080114, 1.6577886004592932]
# [0.1821016402075646, 1.6982960174453055, 0.7320857777127449, 1.2938366859038124, 0.4869544018538263]
# [1.7002822834518914, 0.792313820502741, 2.0490052760366244, -0.7854101411140949, 2.1052280147592115]
# [1.6842838363794688, 0.5003637688215303, 0.5145980882566028, -0.35648336004217607, 1.3537349806738883]
# [1.7879569331460041, 1.8849023538126706, -1.3787419299152093, 2.449807622607384, 1.5100027657492143]
# [1.904563159131777, 1.5638208309500572, 1.7142651861533562, -0.9150304229068034, 1.5675256317165058]
# [0.9885545503233811, 1.365227963044235, 0.23128751671413875, 1.4983078844890647, -0.21912510151242184]
# [1.5512212242903638, 2.009450876438882, 0.5774815330222374, 1.7095912747053983, 1.2795044204259638]
# [1.578486958564972, -0.08726390673360383, 1.0158924476521223, 1.3160759310996024, -0.47699736429348916]
# [1.9831591900278585, 0.8661787705144318, -1.2401543466104552, 1.9691654896381054]
# 'LINxPER'

# %% [markdown]
# ### Gaussian Process

# %%
ripl.bind_foreign_sp("make_gp_part_der",gp_with_derivatives.makeGPSP)

# %%
#ripl.assume('cov','(apply_function  func_times  per lin )')
ripl.assume('gp','(tag (quote parameter) 0 (make_gp_part_der zero grammar))')

# %% [markdown]
# ## Plot the Prior

# %%
def genSamples(x):
    sampleString='(gp (array '
    for i in range(len(x)):
        sampleString+= str(x[i]) + ' ' 
    sampleString+='))'
    #print(sampleString)
    return sampleString

# %%
dataset=ripl.infer("(collect interp )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["interp"].value_counts().plot(kind="bar")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)

for i in range(100):
    xpost= np.random.uniform(low=0.0, high=10.0, size=50)
    sampleString=genSamples(xpost)
    ypost = ripl.sample(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()

# %%
def makeObservations(x,y):
    print(y)
    xString = genSamples(x)
    ripl.observe(xString, array(y.tolist()))
    #ripl.observe('(gp (array -3 4))', array([-1, 1]))
    
makeObservations(xtrain,ytrain)
# Out:
# [ -1.08270008   1.65617305  19.51913055   3.93392411   6.7345384
#    2.0777363   10.126807     7.67180213  20.16739748   2.46033042
#    7.52825019   4.99484024  14.85208529  17.04116647  14.29386719
#   -0.39957988  14.41562832   3.0885509    6.99606813  16.88261598
#   13.95454574  18.20335834   4.67151946   3.66894069  19.16308517
#   15.99708341  15.68900817   2.45549565  13.18816859  12.84856905]

# %%
'''
dataset=ripl.infer("(collect (a 0)  (l 0) (p 0) (sf 0) sn )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(a 0.0)"].plot(kind="hist")   
'''
# Out:
# '\ndataset=ripl.infer("(collect (a 0)  (l 0) (p 0) (sf 0) sn )")\ndf =dataset.asPandas()\nfig = plt.figure(figsize=(figlength,figheigth), dpi=200)\ndf["(a 0.0)"].plot(kind="hist")   \n'

# %%
'''
cycle=10
for i in range(cycle):
    ripl.infer("(repeat 5 (do (hmc parameter all 10 10 3) (mh hypers 0 1) (mh hypers 1 1)(mh hypers 2 1)) )")
    ripl.infer("(mh complexity one 1)") 
    ripl.infer("(mh grammar one 1 )")    
'''
# Out:
# '\ncycle=10\nfor i in range(cycle):\n    ripl.infer("(repeat 5 (do (hmc parameter all 10 10 3) (mh hypers 0 1) (mh hypers 1 1)(mh hypers 2 1)) )")\n    ripl.infer("(mh complexity one 1)") \n    ripl.infer("(mh grammar one 1 )")    \n'

# %%
cycle=10
for i in range(cycle):
    ripl.infer("(repeat 10 (do (hmc parameter all 10 10 3) (mh hypers all 1) ) )")
    ripl.infer(10)

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)

for i in range(100):
    xpost= np.random.uniform(low=0.0, high=10.0, size=50)
    sampleString=genSamples(xpost)
    ypost = ripl.sample(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()

# %%
'''
cycle=5
for i in range(cycle):
    ripl.infer("(hmc parameter all 10 10 3)")
    ripl.infer("(mh hypers_lin all 1)") 
'''
# Out:
# '\ncycle=5\nfor i in range(cycle):\n    ripl.infer("(hmc parameter all 10 10 3)")\n    ripl.infer("(mh hypers_lin all 1)") \n'

# %%
dataset=ripl.infer("(collect interp )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["interp"].value_counts().plot(kind="bar")

# %%
dataset=ripl.infer("(collect (a 0)  (l 0) (p 0) (sf 0) sn )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(a 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(l 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(sf 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(p 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["sn"].plot(kind="hist")

# %%
'''
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
for i in range(20):
    xpost= np.random.uniform(low=0.0, high=10.0, size=10)
    sampleString=genSamples(xpost)
    ypost = ripl.predict(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
'''
# Out:
# '\nfig = plt.figure(figsize=(figlength,figheigth), dpi=200)\nfor i in range(20):\n    xpost= np.random.uniform(low=0.0, high=10.0, size=10)\n    sampleString=genSamples(xpost)\n    ypost = ripl.predict(sampleString)\n    yp = [y for (x,y) in sorted(zip(xpost,ypost))]\n    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)\n    \npl.plot(actual_x,actual_f,c="#3498db")\npl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)\npl.xlim(xa,xb)\npl.ylim(ya,yb)\n'
