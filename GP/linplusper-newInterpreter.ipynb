# %%
from venture import shortcuts


import numpy as np
import numpy.linalg as la
import numpy.random as npr
import scipy.spatial.distance as spdist

from venture.lite.function import VentureFunction
from venture.lite.sp import SPType
import venture.lite.types as t
import venture.value.dicts as d
from venture.lite.builtin import typed_nr

import pylab as pl
import seaborn
from IPython.display import display, Math, Latex
import scipy.io as sio
import timeit
import itertools

import sys
sys.path.append('../SPs/')
from grammar5 import Grammar
from kernel_interpreter_new import GrammarInterpreter
import gp_der as gp_with_derivatives
from covFunctions import *


figlength = 16
figheigth = 8
figlength = 16
figheigth = 8
xa = 0
xb = 10

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['array']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
constantType = SPType([t.AnyType()], t.NumberType())
def makeConstFunc(c):
  return VentureFunction(lambda _: c, sp_type=constantType)
def array(xs):
  return t.VentureArrayUnboxed(np.array(xs),  t.NumberType())
covfunctionType = SPType([t.NumberType(), t.NumberType()], t.NumberType())

# %%
ripl = shortcuts.make_lite_church_prime_ripl()

# %% [markdown]
# #### Zero Mean

# %%
ripl.assume('make_const_func', VentureFunction(makeConstFunc, [t.NumberType()], constantType))
ripl.assume('zero', "(apply_function make_const_func 0)")
# Out:
# <function __main__.<lambda>>

# %% [markdown]
# #### LIN

# %% [markdown]
# ## Hyperparameters

# %%
ripl.assume('make_linear', VentureFunction(makeLinear, [t.NumberType()], t.AnyType("VentureFunction")))
ripl.assume('make_periodic', VentureFunction(makePeriodic, [t.NumberType(), t.NumberType(), t.NumberType()], t.AnyType("VentureFunction")))
ripl.assume('make_se',VentureFunction(makeSquaredExponential,[t.NumberType(), t.NumberType()], t.AnyType("VentureFunction")))
# Out:
# <function covFunctions.makeSquaredExponential>

# %% [markdown]
# ### WN

# %%
ripl.assume('make_noise', VentureFunction(makeNoise, [t.NumberType()], t.AnyType("VentureFunction")))
# Out:
# <function covFunctions.makeNoise>

# %%
ripl.infer("(resample 10)")
# Out:
# []

# %%
ripl.assume('a','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')
ripl.assume('sn','(tag (quote hypers) 2 (uniform_continuous 0.01 3))')
ripl.assume('sf','(mem (lambda (i) (tag (quote hypers) i(uniform_continuous 0.1 2 ))))')
ripl.assume('sf2','(mem (lambda (i) (tag (quote hypers) i(uniform_continuous 0.1 8 ))))')
ripl.assume('p','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')
ripl.assume('l','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')
ripl.assume('l2','(mem (lambda (i) (tag (quote hypers) i (uniform_continuous 0.1 8))))')


ripl.assume("log_a","(lambda (i) (log (a i)))")
ripl.assume("log_sn","(log sn )")
ripl.assume("log_sf","(lambda (i) (log (sf i)))")
ripl.assume("log_p","(lambda (i) (log (p i)))")
ripl.assume("log_l","(lambda (i) (log (l i)))") 
ripl.assume("log_sf2","(lambda (i) (log (sf2 i)))") 
ripl.assume("log_l2","(lambda (i) (log (l2 i)))")
# Out:
# 'unknown spAux'

# %%
ripl.assume('lin1', "(apply_function make_linear (log_a 0)  )")
ripl.assume('lin2', "(apply_function make_linear (log_a 1)  )")
ripl.assume('lin3', "(apply_function make_linear (log_a 2)  )")
ripl.assume('per1', "(apply_function make_periodic (log_l 3) (log_p 3) (log_sf 3) )")
ripl.assume('se1', "(apply_function make_se (log_sf2 4) (log_l2 4))")
ripl.assume('se2', "(apply_function make_se (log_sf2 5) (log_l2 5))")
# Out:
# <function covFunctions.f>

# %% [markdown]
# ## Underlying Ground Truth

# %%
ground_truth = "periodicpluslinear"

# %%
if ground_truth == "periodicpluslinear":
    ripl.assume('noise','(lambda (x) (normal 0 0.7))')
    ripl.assume('true_function','(lambda ( x)   ( + (* 2 x ) (* 2 (sin (* 5 x ))))  )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = 2 * x  + 2 \sin (5 x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.7)'))
    ya = 0 # plotting parameter
    yb =20
# Out:
# $$y = f(x) + \eta_x = 2 * x  + 2 \sin (5 x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.7)$$

# %%
if ground_truth == "periodictimeslinear":
    ripl.assume('noise','(lambda (x) (normal 0 0.7))')
    ripl.assume('true_function','(lambda ( x)   ( * (* 2 x ) (sin (* 5 x )))  )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = 2 * x  * \sin (5 x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.7)'))
    ya =-20 # plotting parameter
    yb =20

# %% [markdown]
# ### Sample Training Data

# %%
n = 30
xtrain = np.random.uniform(0,10,n)
ytrain = np.zeros((xtrain.shape))
for i in range(n): 
     sample_from_y= "( y %f )" % xtrain[i]
     ytrain[i]=ripl.sample(sample_from_y)

# %% [markdown]
# #### For plotting the actual function, we sample from the real thing:

# %%
n = 200
actual_x = np.linspace(0,10,n)
actual_f = np.zeros((actual_x.shape))
for i in range(n): 
     sample_from_f= "( true_function %f )" % actual_x[i]
     actual_f[i]=ripl.sample(sample_from_f)

# %% [markdown]
# ### make covs in ripl

# %%
ripl.assume('wn', "(apply_function make_noise sn)")
# Out:
# <function covFunctions.f>

# %% [markdown]
# ### GP Structure Prior

# %% [markdown]
# ##### for simplicity, I start with the max amount of kernel per type given

# %%
ripl.assume("max_lin","(array  lin1 lin2 lin3 )")
ripl.assume("max_per","(array  per1 )")
ripl.assume("max_se","(array  se1 se2)")
ripl.assume("max_wn","(array wn)")
# Out:
# [<function covFunctions.f>]

# %%
number = 7
simplex = "( simplex  "
total_perms =0
perms = []
for i in range(number):
    perms.append((len(list(itertools.permutations([j for j in range(i+1)])))))
    total_perms+=perms[i]
    
simplex = "( simplex  "
for i in range(number):
    simplex+=str(float(perms[i])/total_perms) + " "
    
simplex+=" )"

# %%
ripl.assume("number_components","(tag (quote complexity) 0 (categorical "+simplex+"))")
# Out:
# 6

# %%
ripl.bind_foreign_sp("gp_grammar", typed_nr(Grammar(), [t.HomogeneousArrayType(t.HomogeneousArrayType(t.AnyType())),t.AnyType()], covfunctionType, min_req_args=0))

# %%
ripl.assume("grammar","(tag (quote grammar) 0 (gp_grammar (array max_lin max_wn max_per max_se) number_components ))")
# Out:
# <function grammar5.<lambda>>

# %% [markdown]
# #### way so that we can visualize posterior:

# %%
ripl.bind_foreign_sp("covfunc_interpreter",typed_nr(GrammarInterpreter(), [t.AnyType()], t.AnyType()))

# %%
ripl.assume("interp","(covfunc_interpreter grammar)")
# Out:
# [2, 3]
# [3, 4]
# [0, 1]
# [3, 5]
# [4, 5]
# [3, 5]
# [0, 3]
# [1, 6]
# [1, 2]
# [2, 3]
# 'LIN+WN+PERxSE+LINxLINxSE'

# %% [markdown]
# ### Gaussian Process

# %%
ripl.bind_foreign_sp("make_gp_part_der",gp_with_derivatives.makeGPSP)

# %%
#ripl.assume('cov','(apply_function  func_times  per lin )')
ripl.assume('gp','(tag (quote parameter) 0 (make_gp_part_der zero grammar))')

# %% [markdown]
# ## Plot the Prior

# %%
def genSamples(x):
    sampleString='(gp (array '
    for i in range(len(x)):
        sampleString+= str(x[i]) + ' ' 
    sampleString+='))'
    #print(sampleString)
    return sampleString

# %%
dataset=ripl.infer("(collect interp )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["interp"].value_counts().plot(kind="bar")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)

for i in range(100):
    xpost= np.random.uniform(low=0.0, high=10.0, size=50)
    sampleString=genSamples(xpost)
    ypost = ripl.sample(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()

# %%
def makeObservations(x,y):
    print(y)
    xString = genSamples(x)
    ripl.observe(xString, array(y.tolist()))
    #ripl.observe('(gp (array -3 4))', array([-1, 1]))
    
makeObservations(xtrain,ytrain)
# Out:
# [ 10.68147738   9.21254148  19.27614641  13.75460545  15.49508208
#   16.03476215   4.07252197   8.34501741   8.14842281   8.35998747
#    4.72287485   7.72740836   9.60016711   6.03706658  13.45341843
#    2.41655916   5.01554736  14.10044127   6.86845163  18.34068163
#   14.92854629   8.76337986  13.19916253   2.86581561  10.67475135
#   18.43831864   8.90036477   5.81425114  18.4702157    5.96246359]

# %%
'''
dataset=ripl.infer("(collect (a 0)  (l 0) (p 0) (sf 0) sn )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(a 0.0)"].plot(kind="hist")   
'''
# Out:
# '\ndataset=ripl.infer("(collect (a 0)  (l 0) (p 0) (sf 0) sn )")\ndf =dataset.asPandas()\nfig = plt.figure(figsize=(figlength,figheigth), dpi=200)\ndf["(a 0.0)"].plot(kind="hist")   \n'

# %%
cycle=10
for i in range(cycle):
    ripl.infer("(repeat 10 (do (hmc (quote parameter) all 10 10 3) (mh (quote hypers) all 1) ) )")
    ripl.infer(10)
# Out:
# [0, 2]
# [0, 4]
# [0, 1]
# [3, 5]
# [2, 3]
# [0, 5]
# [2, 3]
# [0, 1]
# [2, 5]
# [3, 6]
# [2, 3]
# [5, 6]
# [0, 1]
# [0, 5]
# [2, 4]
# [4, 5]
# [1, 2]
# [2, 4]
# [5, 6]
# [0, 1]
# [5, 6]
# [0, 6]
# [0, 2]
# [1, 2]
# [2, 3]
# [2, 4]
# [2, 3]
# [5, 6]
# [2, 4]
# [1, 6]
# [2, 3]
# [3, 5]
# [0, 3]
# [1, 2]
# [1, 6]
# [3, 4]
# [0, 3]
# [5, 6]
# [1, 2]
# [2, 5]
# [1, 3]
# [0, 2]
# [2, 4]
# [0, 4]
# [3, 5]
# [0, 6]
# [0, 1]
# [3, 4]
# [0, 1]
# [5, 6]
# [2, 4]
# [1, 2]
# [0, 4]
# [1, 5]
# [2, 5]
# [4, 6]
# [5, 6]
# [2, 4]
# [3, 6]
# [1, 4]
# [0, 1]
# [3, 4]
# [1, 4]
# [4, 5]
# [2, 3]
# [4, 5]
# [0, 2]
# [0, 1]
# [1, 5]
# [3, 6]
# [4, 6]
# [1, 3]
# [1, 6]
# [4, 5]
# [2, 4]
# [2, 4]
# [2, 5]
# [2, 3]
# [1, 4]
# [0, 2]
# [2, 6]
# [0, 3]
# [5, 6]
# [2, 5]
# [1, 2]
# [2, 3]
# [4, 5]
# [1, 5]
# [2, 6]
# [0, 3]
# [0, 1]
# [2, 4]
# [0, 5]
# [1, 4]
# [5, 6]
# [1, 2]
# [5, 6]
# [4, 6]
# [2, 4]
# [3, 5]
# [4, 6]
# [1, 3]
# [1, 5]
# [3, 4]
# [2, 3]
# [2, 3]
# [3, 5]
# [0, 4]
# [5, 6]
# [5, 6]
# [3, 5]
# [1, 2]
# [5, 6]
# [1, 3]
# [2, 4]
# [0, 2]
# [5, 6]
# [5, 6]
# [2, 3]
# [0, 3]
# [1, 3]
# [0, 4]
# [2, 5]
# [2, 6]
# [0, 1]
# [0, 2]
# [0, 1]
# [2, 6]
# [1, 4]
# [0, 1]
# [1, 6]
# [3, 4]
# [1, 6]
# [0, 6]
# [0, 3]
# [1, 3]
# [1, 3]
# [2, 3]
# [2, 3]
# [4, 6]
# [4, 5]
# [0, 2]
# [1, 3]
# [1, 5]
# [2, 5]
# [4, 6]
# [3, 5]
# [1, 5]
# [0, 5]
# [2, 3]
# [0, 6]
# [1, 6]
# [1, 2]
# [3, 4]
# [4, 6]
# [3, 5]
# [1, 2]
# [0, 1]
# [0, 1]
# [2, 3]
# [2, 3]
# [0, 1]
# [3, 5]
# [0, 3]
# [1, 5]
# [1, 2]
# [3, 5]
# [1, 5]
# [0, 6]
# [2, 6]
# [1, 5]
# [1, 6]
# [0, 1]
# [2, 4]
# [0, 3]
# [1, 4]
# [2, 4]
# [0, 2]
# [0, 4]
# [4, 5]
# [0, 2]
# [0, 3]
# [4, 6]
# [5, 6]
# [5, 6]
# [5, 6]
# [1, 4]
# [5, 6]
# [3, 4]
# [2, 3]
# [4, 6]
# [3, 5]
# [0, 1]
# [0, 1]
# [3, 4]
# [5, 6]
# [2, 3]
# [1, 5]
# [1, 5]
# [3, 4]
# [3, 5]
# [0, 1]
# [4, 5]
# [1, 3]
# [4, 5]
# [4, 5]
# [1, 3]
# [1, 2]
# [3, 4]
# [1, 6]
# [0, 3]
# [3, 4]
# [5, 6]
# [0, 1]
# [5, 6]
# [0, 3]
# [5, 6]
# [5, 6]
# [1, 3]
# [4, 6]
# [2, 3]
# [1, 2]
# [2, 4]
# [5, 6]
# [3, 4]
# [0, 4]
# [0, 1]
# [1, 2]
# [3, 4]
# [0, 1]
# [0, 3]
# [1, 5]
# [1, 3]
# [0, 2]
# [1, 5]
# [3, 6]
# [0, 6]
# [5, 6]
# [4, 5]
# [0, 1]
# [0, 1]
# [3, 4]
# [4, 6]
# [0, 5]
# [3, 4]
# [1, 3]
# [5, 6]
# [0, 3]
# [0, 3]
# [1, 6]
# [3, 4]
# [1, 6]
# [2, 4]
# [2, 6]
# [3, 6]
# [3, 4]
# [1, 6]
# [1, 4]
# [0, 1]
# [5, 6]
# [1, 6]
# [2, 6]
# [2, 4]
# [4, 6]
# [1, 4]
# [0, 2]
# [2, 6]
# [1, 5]
# [0, 6]
# [0, 3]
# [2, 6]
# [1, 4]
# [1, 5]
# [1, 6]
# [2, 4]
# [0, 4]
# [3, 4]
# [0, 2]
# [3, 6]
# [2, 5]
# [5, 6]
# [5, 6]
# [2, 6]
# [1, 3]
# [5, 6]
# [2, 3]
# [0, 5]
# [5, 6]
# [5, 6]
# [0, 1]
# [0, 6]
# [3, 4]
# [1, 4]
# [0, 4]
# [5, 6]
# [2, 3]
# [1, 6]
# [2, 3]
# [0, 6]
# [1, 5]
# [4, 6]
# [0, 3]
# [1, 3]
# [2, 5]
# [2, 3]
# [0, 1]
# [5, 6]
# [5, 6]
# [2, 5]
# [0, 5]
# [1, 4]
# [0, 2]
# [5, 6]
# [2, 3]
# [3, 4]
# [1, 5]
# [5, 6]
# [2, 3]
# [4, 5]
# [4, 6]
# [3, 5]
# [2, 4]
# [5, 6]
# [1, 5]
# [2, 4]
# [2, 4]
# [1, 3]
# [4, 5]
# [2, 4]
# [1, 5]
# [0, 2]
# [2, 6]
# [5, 6]
# [2, 3]
# [0, 6]
# [0, 5]
# [1, 4]
# [0, 1]
# [0, 6]
# [1, 4]
# [3, 4]
# [5, 6]
# [2, 5]
# [2, 4]
# [5, 6]
# [0, 3]
# [4, 6]
# [5, 6]
# [1, 2]
# [5, 6]
# [5, 6]
# [4, 5]
# [2, 4]
# [0, 3]
# [0, 2]
# [4, 5]
# [1, 5]
# [5, 6]
# [4, 5]
# [4, 5]
# [0, 3]
# [2, 4]
# [2, 3]
# [4, 5]
# [3, 5]
# [1, 6]
# [0, 4]
# [4, 5]
# [5, 6]
# [2, 3]
# [0, 2]
# [5, 6]
# [4, 5]
# [0, 2]
# [1, 3]
# [4, 6]
# [3, 5]
# [1, 3]
# [3, 4]
# [3, 4]
# [0, 2]
# [1, 2]
# [2, 3]
# [5, 6]
# [4, 5]
# [1, 2]
# [2, 3]
# [3, 6]
# [1, 6]
# [5, 6]
# [3, 6]
# [0, 3]
# [2, 5]
# [0, 1]
# [5, 6]
# [2, 4]
# [2, 4]
# [1, 2]
# [3, 4]
# [1, 3]
# [1, 4]
# [0, 5]
# [1, 5]
# [2, 3]
# [3, 5]
# [0, 2]
# [2, 4]
# [3, 4]
# [1, 3]
# [3, 4]
# [1, 3]
# [5, 6]
# [1, 4]
# [3, 6]
# [4, 6]
# [0, 5]
# [0, 6]
# [3, 6]
# [3, 5]
# [0, 5]
# [3, 6]
# [5, 6]
# [1, 2]
# [2, 4]
# [2, 3]
# [0, 2]
# [0, 5]
# [1, 3]
# [0, 3]
# [3, 4]
# [3, 6]
# [5, 6]
# [1, 2]
# [5, 6]
# [2, 4]
# [3, 4]
# [3, 4]
# [3, 4]
# [2, 4]
# [4, 5]
# [4, 6]
# [1, 2]
# [0, 1]
# [2, 6]
# [1, 3]
# [1, 3]
# [2, 6]
# [1, 3]
# [0, 3]
# [1, 3]
# [0, 1]
# [2, 4]
# [2, 3]
# [0, 3]
# [1, 2]
# [1, 2]
# [1, 3]
# [0, 1]
# [5, 6]
# [1, 6]
# [3, 4]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-74ce8bb64636> in <module>()
#       1 cycle=10
#       2 for i in range(cycle):
# ----> 3     ripl.infer("(repeat 10 (do (hmc (quote parameter) all 10 10 3) (mh (quote hypers) all 1) ) )")
#       4     ripl.infer(10)
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in infer(self, params, type, suppress_pausing_continous_inference)
#     595         # The suppress_pausing_continous_inference flag is used by the
#     596         # thread doing the continuous inference.
# --> 597         o = self.execute_instruction({'instruction':'infer', 'expression': self.defaultInferProgram(params)}, suppress_pausing_continous_inference=suppress_pausing_continous_inference)
#     598         value = o["value"]
#     599         return value if type else u.strip_types(value)
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params, suppress_pausing_continous_inference)
#     130                 stringable_instruction = instruction
#     131                 parsed_instruction = self._ensure_parsed(instruction)
# --> 132             ret_value = self.sivm.execute_instruction(parsed_instruction, suppress_pausing_continous_inference=suppress_pausing_continous_inference)
#     133         except VentureException as e:
#     134             import sys
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction, suppress_pausing_continous_inference)
#      68                 return f(instruction)
#      69             else:
# ---> 70                 response = self._call_core_sivm_instruction(instruction)
#      71                 return response
#      72
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     129             desugared_src_location['expression_index'] = new_index
#     130         try:
# --> 131             response = self.core_sivm.execute_instruction(desugared_instruction)
#     132         except VentureException as e:
#     133             # raise # One can suppress error annotation by uncommenting this
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      44         utils.validate_instruction(instruction,self._implemented_instructions)
#      45         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 46         return f(instruction)
#      47
#      48     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_infer(self, instruction)
#     151         e = utils.validate_arg(instruction,'expression',
#     152                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# --> 153         val = self.engine.infer(e)
#     154         return {"value":val}
#     155
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in infer(self, program)
#     185     else:
#     186       with self.inference_trace():
# --> 187         did = self._do_infer(program)
#     188         ans = self._extract_infer_result(did)
#     189         self.infer_trace.uneval(did) # TODO This becomes "forget" after the engine.Trace wrapper
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in _do_infer(self, program)
#     196     self.directiveCounter += 1
#     197     did = self.directiveCounter # Might be mutated by reentrant execution
# --> 198     self.infer_trace.eval(did, [program, v.blob(Infer(self))])
#     199     return did
#     200
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/trace.pyc in eval(self, id, exp)
#     356   def eval(self,id,exp):
#     357     assert not id in self.families
# --> 358     (_,self.families[id]) = evalFamily(self,Address(List(id)),self.unboxExpression(exp),self.globalEnv,Scaffold(),False,OmegaDB(),{})
#     359
#     360   def bindInGlobalEnv(self,sym,id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     139     for index, subexp in enumerate(exp):
#     140       addr = address.extend(index)
# --> 141       w, n = evalFamily(trace,addr,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     142       weight += w
#     143       nodes.append(n)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     139     for index, subexp in enumerate(exp):
#     140       addr = address.extend(index)
# --> 141       w, n = evalFamily(trace,addr,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     142       weight += w
#     143       nodes.append(n)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     139     for index, subexp in enumerate(exp):
#     140       addr = address.extend(index)
# --> 141       w, n = evalFamily(trace,addr,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     142       weight += w
#     143       nodes.append(n)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     139     for index, subexp in enumerate(exp):
#     140       addr = address.extend(index)
# --> 141       w, n = evalFamily(trace,addr,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     142       weight += w
#     143       nodes.append(n)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     139     for index, subexp in enumerate(exp):
#     140       addr = address.extend(index)
# --> 141       w, n = evalFamily(trace,addr,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     142       weight += w
#     143       nodes.append(n)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     139     for index, subexp in enumerate(exp):
#     140       addr = address.extend(index)
# --> 141       w, n = evalFamily(trace,addr,subexp,env,scaffold,shouldRestore,omegaDB,gradients)
#     142       weight += w
#     143       nodes.append(n)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 171   weight += applyPSP(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     172   assert isinstance(weight, numbers.Number)
#     173   return weight
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in applyPSP(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199   else:
#     200     # if we simulate from the prior, the weight is 0
# --> 201     newValue = psp.simulate(args) if not shouldRestore else oldValue
#     202
#     203   trace.setValueAt(node,newValue)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/psp.pyc in simulate(self, args)
#     349
#     350   def simulate(self,args):
# --> 351     return self.f_type.wrap_return(self.psp.simulate(self.f_type.unwrap_args(args)))
#     352   def gradientOfSimulate(self, args, value, direction):
#     353     # TODO Should gradientOfSimulate unwrap the direction and wrap the
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/inference_sps.pyc in simulate(self, args)
#      46     self.exp = [name] + exp
#      47   def simulate(self, args):
# ---> 48     ans = args.operandValues[0].primitive_infer(self.exp)
#      49     return (ans, args.operandValues[0])
#      50
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/inference.pyc in primitive_infer(self, exp)
#      88       return item
#      89
# ---> 90   def primitive_infer(self, exp): self.engine.primitive_infer(exp)
#      91   def resample(self, ct): self.engine.resample(ct, 'sequential')
#      92   def resample_serializing(self, ct): self.engine.resample(ct, 'serializing')
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in primitive_infer(self, exp)
#     244       self._define_in(name, exp, next_trace)
#     245
# --> 246   def primitive_infer(self, exp): self.model.primitive_infer(exp)
#     247   def logscore(self): return self.model.logscore()
#     248   def logscore_all(self): return self.model.logscore_all()
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/trace_set.pyc in primitive_infer(self, exp)
#     194
#     195   def primitive_infer(self, exp):
# --> 196     self.traces.map('primitive_infer', exp)
#     197
#     198   def logscore(self): return self.traces.at_distinguished('getGlobalLogScore')
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in map(self, cmd, *args, **kwargs)
#     185     '''Delegate command to all workers'''
#     186     # send command
# --> 187     for pipe in self.pipes: pipe.send((cmd, args, kwargs, None))
#     188     if cmd == 'stop': return
#     189     res = []
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in send(self, obj)
#     516
#     517   def send(self, obj):
# --> 518     self.other.emplace(obj)
#     519
#     520   def emplace(self, obj):
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in emplace(self, obj)
#     521     self.objs.append(obj)
#     522     for cb in self.cbs:
# --> 523       cb()
#     524
#     525   def recv(self):
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in poll(self)
#     338       res = getattr(self.objs[index], cmd)(*args, **kwargs)
#     339     else:
# --> 340       res = [getattr(o, cmd)(*args, **kwargs) for o in self.objs]
#     341     self.pipe.send(res)
#     342
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in wrapped(*args, **kwargs)
#      90   def wrapped(*args, **kwargs):
#      91     try:
# ---> 92       res = f(*args, **kwargs)
#      93     except Exception:
#      94       # If I return the traceback object and try to format it
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/trace.pyc in primitive_infer(self, exp)
#     453     for _ in range(transitions):
#     454       if operator == "mh":
# --> 455         mixMH(self, BlockScaffoldIndexer(scope, block), MHOperator())
#     456       elif operator == "draw_scaffold":
#     457         drawScaffold(self, BlockScaffoldIndexer(scope, block))
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/infer/mh.pyc in mixMH(trace, indexer, operator)
#      72   else:
#      73 #    sys.stdout.write("!")
# ---> 74     operator.reject() # May mutate trace
#      75     accepted = False
#      76
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/infer/mh.pyc in reject(self)
#     141   def accept(self): pass
#     142   def reject(self):
# --> 143     detachAndExtract(self.trace,self.scaffold)
#     144     regenAndAttach(self.trace,self.scaffold,True,self.rhoDB,{})
#     145
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/detach.pyc in detachAndExtract(trace, scaffold, compute_gradient)
#      26   assertTrace(trace, scaffold)
#      27   assert len(scaffold.border) == 1
# ---> 28   ans = detachAndExtractAtBorder(trace, scaffold.border[0], scaffold, compute_gradient=compute_gradient)
#      29   assertTorus(scaffold)
#      30   return ans
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/detach.pyc in detachAndExtractAtBorder(trace, border, scaffold, compute_gradient)
#      41   for node in reversed(border):
#      42     if scaffold.isAbsorbing(node):
# ---> 43       weight += detach(trace, node, scaffold, omegaDB, compute_gradient)
#      44     else:
#      45       if node.isObservation: weight += unconstrain(trace,trace.getConstrainableNode(node))
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/detach.pyc in detach(trace, node, scaffold, omegaDB, compute_gradient)
#      65     (_, grad) = psp.gradientOfLogDensity(gvalue, args)
#      66     omegaDB.addPartials(args.operandNodes + trace.esrParentsAt(node), grad)
# ---> 67   weight += extractParents(trace, node, scaffold, omegaDB, compute_gradient)
#      68   return weight
#      69
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/detach.pyc in extractParents(trace, node, scaffold, omegaDB, compute_gradient)
#      73     weight += extract(trace, parent, scaffold, omegaDB, compute_gradient)
#      74   for parent in reversed(trace.definiteParentsAt(node)):
# ---> 75     weight += extract(trace, parent, scaffold, omegaDB, compute_gradient)
#      76   return weight
#      77
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/detach.pyc in extract(trace, node, scaffold, omegaDB, compute_gradient)
#      84 def extract(trace, node, scaffold, omegaDB, compute_gradient = False):
#      85   weight = 0
# ---> 86   value = trace.valueAt(node)
#      87   if isinstance(value,SPRef) and value.makerNode != node and scaffold.isAAA(value.makerNode):
#      88     weight += extract(trace, value.makerNode, scaffold, omegaDB, compute_gradient)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/trace.pyc in valueAt(self, node)
#     214
#     215   def valueAt(self,node):
# --> 216     assert node.isAppropriateValue(node.value)
#     217     return node.value
#     218
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)

for i in range(100):
    xpost= np.random.uniform(low=0.0, high=10.0, size=50)
    sampleString=genSamples(xpost)
    ypost = ripl.sample(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()

# %%
'''
cycle=5
for i in range(cycle):
    ripl.infer("(hmc parameter all 10 10 3)")
    ripl.infer("(mh hypers_lin all 1)") 
'''

# %%
dataset=ripl.infer("(collect interp )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["interp"].value_counts().plot(kind="bar")

# %%
dataset=ripl.infer("(collect (a 0)  (l 0) (p 0) (sf 0) sn )")
df =dataset.asPandas()
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(a 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(l 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(sf 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["(p 0.0)"].plot(kind="hist")

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
df["sn"].plot(kind="hist")

# %%
'''
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
for i in range(20):
    xpost= np.random.uniform(low=0.0, high=10.0, size=10)
    sampleString=genSamples(xpost)
    ypost = ripl.predict(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
'''
