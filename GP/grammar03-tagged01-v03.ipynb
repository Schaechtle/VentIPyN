# %%
from venture import shortcuts


import numpy as np
import numpy.linalg as la
import numpy.random as npr
import scipy.spatial.distance as spdist

from venture.lite.function import VentureFunction
from venture.lite.sp import SPType
import venture.lite.value as v
import venture.value.dicts as d
from venture.lite.builtin import typed_nr

import pylab as pl
import seaborn
from IPython.display import display, Math, Latex

import timeit

import sys
sys.path.append('../SPs/')
from grammar3 import Grammar
from grammarinterpreter import GrammarInterpreter
import gp_withDer as gp_with_derivatives

figlength = 16
figheigth = 8
xa = 0
xb = 10

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
constantType = SPType([v.AnyType()], v.NumberType())
def makeConstFunc(c):
  return VentureFunction(lambda _: c, sp_type=constantType)

# %%
def array(xs):
  return v.VentureArrayUnboxed(np.array(xs),  v.NumberType())

# %%
covfunctionType = SPType([v.NumberType(), v.NumberType()], v.NumberType())

# %% [markdown]
# ### Squared Exponential Covariance Function

# %%
def squared_exponential(sf, l):
  def f(x1, x2):
    A = spdist.cdist(x1/l,x2/l,'sqeuclidean')
    return sf * np.exp(-0.5*A)
  return f
# gradient
def squared_exponential_der_l(sf, l):
  def f(x1, x2):
    A = spdist.cdist(x1/l,x2/l,'sqeuclidean')
    return sf2 * np.exp(-0.5*A) * A
  return f
def squared_exponential_der_sf(sf, l):
  def f(x1, x2):
    A = spdist.cdist(x1/l,x2/l,'sqeuclidean')
    return  2. * sf2 * np.exp(-0.5*A)
  return f



squaredExponentialType = SPType([v.NumberType(), v.NumberType()], v.NumberType())
def makeSquaredExponential(sf, l): 
  return VentureFunction(squared_exponential(sf, l), sp_type=squaredExponentialType,derivatives={0:squared_exponential_der_l(sf,l),1:squared_exponential_der_sf(sf,l)},name="SE")

# %% [markdown]
# ### Periodic Covariance Function

# %%
def periodic(sf,p,l):
  def f(x1, x2):
    A = np.sqrt(spdist.cdist(x1,x2,'sqeuclidean'))
    A = np.pi*A/p
    A = np.sin(A)/l
    A = A * A
    A = sf *np.exp(-2.*A)
    return A
  return f

# %% [raw]
# gradient

# %%
def periodic_der_l(sf,p,l):
  def f(x1, x2):
    A = np.sqrt(spdist.cdist(x1,x2,'sqeuclidean'))
    A = np.pi*A/p
    A = np.sin(A)/ell
    A = A * A
    A = 4. *sf2 *np.exp(-2.*A) * A
    return A
  return f
def periodic_der_p(sf,p,l):
  def f(x1, x2):
    A = np.sqrt(spdist.cdist(x1,x2,'sqeuclidean'))
    A = np.pi*A/p
    R = np.sin(A)/ell
    A = 4 * sf2/ell * np.exp(-2.*R*R)*R*np.cos(A)*A
    return A
  return f
def periodic_der_sf(sf,p, l):
  def f(x1, x2):
    A = np.sqrt(spdist.cdist(x1,x2,'sqeuclidean'))
    A = np.pi*A/p
    A = np.sin(A)/ell
    A = A * A
    A = 2. * sf2 * np.exp(-2.*A)
    return A
  return f

def makePeriodic(sf,p,l):  
  return VentureFunction(periodic(sf,p,l), sp_type=covfunctionType,derivatives={0:periodic_der_l(sf,p,l),1:periodic_der_p(sf,p,l),2:periodic_der_sf(sf,p,l)},name="PER")

# %% [markdown]
# ### Linear Covariance Function

# %%
def linear(sf):
  def f(x1, x2):
    A = np.dot(x1,x2.T) + 1e-10    # required for numerical accuracy
    return sf * A
  return f
# gradient
def linear_der_sf(sf):
  def f(x1, x2):
    A = np.dot(x1,x2.T)
    return 2 * sf * A
  return f


def makeLinear(sf): 
  return VentureFunction(linear(sf), sp_type=covfunctionType,derivatives={0:linear_der_sf(f)},name="LIN")

# %% [markdown]
# ### White Noise Covariance Function

# %%
def noise(s):
  def f(x1, x2):
    tol = 1.e-9                       # Tolerance for declaring two vectors "equal"
    M = spdist.cdist(x1, x2, 'sqeuclidean')
    A = np.zeros_like(M,dtype=np.float)
    A[M < tol] = 1.
    A = s*A
    return A
  return f
# gradient
def noise_der(s):
  def f(x1, x2):
    tol = 1.e-9                       # Tolerance for declaring two vectors "equal"
    M = spdist.cdist(x1, x2, 'sqeuclidean')
    A = np.zeros_like(M,dtype=np.float)
    A[M < tol] = 1.
    A = 2.*s*A
    return A
  return f

def makeNoise(s): 
  return VentureFunction(noise(s), sp_type=covfunctionType,derivatives={0:noise_der(f)},name="WN")

# %% [markdown]
# ### Binary Operators

# %%
def lift_binary(op):
  def lifted(f1, f2):
    return lambda *xs: op(f1(*xs), f2(*xs))
  return lifted


liftedBinaryType = SPType([v.AnyType(), v.AnyType()], v.AnyType())

def makeLiftedAdd(op):
  lifted_op = lift_binary(op)
  def wrapped(f1, f2):
    sp_type = f1.sp_type
    assert(f2.sp_type == sp_type)
    der={}
    for i in range(len(f1.stuff['derivatives'])):
        der[i]=f1.stuff['derivatives'][i]
    for j in range(len(f2.stuff['derivatives'])):
        der[i+1+j]=f2.stuff['derivatives'][j]
    return VentureFunction(lifted_op(f1, f2), sp_type=sp_type,derivatives=der,name=f1.stuff['name']+"+"+f2.stuff['name'])
  return VentureFunction(wrapped, sp_type=liftedBinaryType)

def makeLiftedMult(op):
  lifted_op = lift_binary(op)
  def wrapped(f1, f2):
    sp_type = f1.sp_type
    assert(f2.sp_type == sp_type)
    der={}
    for i in range(len(f1.stuff['derivatives'])):
        der[i]= lambda *xs: np.dot(f1.stuff['derivatives'][i](*xs),f2.f(*xs))
    for j in range(len(f2.stuff['derivatives'])):
        der[i+1+j]= lambda *xs: np.dot(f2.stuff['derivatives'][j](*xs),f1.f(*xs))
    return VentureFunction(lifted_op(f1,f2), sp_type=sp_type,derivatives=der,name=f1.stuff['name']+"x"+f2.stuff['name'])
  return VentureFunction(wrapped, sp_type=liftedBinaryType)

# %%
ripl = shortcuts.make_lite_church_prime_ripl()

# %% [markdown]
# #### Zero Mean

# %%
ripl.assume('make_const_func', VentureFunction(makeConstFunc, [v.NumberType()], constantType))
ripl.assume('zero', "(apply_function make_const_func 0)")
# Out:
# <function __main__.<lambda>>

# %% [markdown]
# ## Hyperparameters

# %%
ripl.assume('a','(scope_include (quote hypers) 0 (lambda ( ) (gamma 1 2)))')
ripl.assume('l','(scope_include (quote hypers) 1 (lambda ( ) (gamma 2  3)))')
ripl.assume('sf','(scope_include (quote hypers) 2 (lambda ( ) (gamma 1 2)))')
ripl.assume('sn','(scope_include (quote hypers) 3 (lambda ( ) (gamma 1 2)))')
ripl.assume('p','(scope_include (quote hypers) 4 (lambda ( ) (gamma 1 1)))')
# Out:
# 'unknown spAux'

# %% [markdown]
# #### LIN

# %%
ripl.assume('make_linear', VentureFunction(makeLinear, [v.NumberType()], v.AnyType("VentureFunction")))
# Out:
# <function __main__.makeLinear>

# %%
ripl.assume('lin', "(lambda ( ) (apply_function make_linear (a) ))")
# Out:
# 'unknown spAux'

# %% [markdown]
# ### SE

# %%
ripl.assume('make_se', VentureFunction(makeSquaredExponential, [v.NumberType(), v.NumberType()], v.AnyType("VentureFunction")))

ripl.assume('se', "(lambda ( ) (apply_function make_se (sf)  (l)))")
# Out:
# 'unknown spAux'

# %% [markdown]
# ### WN

# %%
ripl.assume('make_noise', VentureFunction(makeNoise, [v.NumberType()], v.AnyType("VentureFunction")))


ripl.assume('wn', "(lambda ( ) (apply_function make_noise (sn)))")
# Out:
# 'unknown spAux'

# %% [markdown]
# #### PER

# %%
ripl.assume('make_periodic', VentureFunction(makePeriodic, [v.NumberType(), v.NumberType(), v.NumberType()], v.AnyType("VentureFunction")))


ripl.assume('per', "(lambda ( ) (apply_function make_periodic (sf) (p) (l)))")
# Out:
# 'unknown spAux'

# %% [markdown]
# ## Underlying Ground Truth

# %%
ground_truth = "linear"

# %%
if ground_truth == "periodic":
    ripl.assume('noise','(lambda (x) (normal 0 0.1))')
    ripl.assume('true_function','(lambda ( x)  (sin (* 3 x ))   )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = \sin (3x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.1)'))
    ya = -5 # plotting parameter
    yb =5

# %%
if ground_truth == "linear":
    ripl.assume('noise','(lambda (x) (normal 0 1))')
    ripl.assume('true_function','(lambda ( x)   (* 2 x )   )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = 2 * x  + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,1)'))
    ya = 0 # plotting parameter
    yb =20
# Out:
# $$y = f(x) + \eta_x = 2 * x  + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,1)$$

# %%
if ground_truth == "periodicpluslinear":
    ripl.assume('noise','(lambda (x) (normal 0 0.7))')
    ripl.assume('true_function','(lambda ( x)   ( + (* 2 x ) (* 2 (sin (* 5 x ))))  )')
    ripl.assume('y','(lambda ( x) ( +  (true_function x) (noise x))  )')
    display(Math(r'y = f(x) + \eta_x = 2 * x  + 2 \sin (5 x) + \eta_x\;\;\;\;\;\;\;\;\eta_x \sim \mathcal{N}(0,0.7)'))
    ya = 0 # plotting parameter
    yb =20

# %% [markdown]
# ## Sample Training Data

# %%
n = 10
xtrain = np.random.uniform(0,10,n)
ytrain = np.zeros((xtrain.shape))
for i in range(n): 
     sample_from_y= "( y %f )" % xtrain[i]
     ytrain[i]=ripl.sample(sample_from_y)

# %% [markdown]
# ### For plotting the actual function, we sample from the real thing:

# %%
n = 200
actual_x = np.linspace(0,10,n)
actual_f = np.zeros((actual_x.shape))
for i in range(n): 
     sample_from_f= "( true_function %f )" % actual_x[i]
     actual_f[i]=ripl.sample(sample_from_f)

# %% [markdown]
# #### Resample to see posterior on structure

# %%
start = timeit.timeit()

# %%
ripl.infer("(resample 10)")
# Out:
# []

# %% [markdown]
# ### GP Structure Prior

# %% [markdown]
# ##### for simplicity, I start with the max amount of kernel per type given

# %%
ripl.assume("max_se","(array (se) (se))")
ripl.assume("max_lin","(array (lin) (lin))")
ripl.assume("max_per","(array (per) (per))")
ripl.assume("max_wn","(array (wn))")
# Out:
# [<function __main__.f>]

# %%
ripl.assume("global_structure_prior","(scope_include (quote global) 0 (beta 1 1))")
# Out:
# 0.8451713009736944

# %%
ripl.assume("get_component_hyperparameter","(scope_include (quote component_hyper) 0 (gamma 1.0 1.0))")
# Out:
# 3.9788336510191664

# %%
ripl.assume("number_of_components_sampler","(scope_include (quote components) 0 (make_uc_sym_dir_mult get_component_hyperparameter 7 (array 1 2 3 4 5 6 7)))")
# Out:
# {'alpha': 3.9788336510191664,
#  'counts': [0, 0, 0, 0, 0, 0, 0],
#  'n': 7,
#  'type': 'uc_sym_dir_mult'}

# %%
ripl.assume("number_of_components","(number_of_components_sampler)")
# Out:
# 2.0

# %%
ripl.assume("global_part","(scope_include (quote components) 1 (binomial ( - number_of_components 1) global_structure_prior))")
# Out:
# 1

# %%
ripl.assume("structure_prior","(scope_include (quote structure) 0 (symmetric_dirichlet 0.5  4))")
# Out:
# array([ 0.08610394,  0.56636208,  0.00197214,  0.34556185])

# %%
ripl.bind_foreign_sp("gp_grammar", typed_nr(Grammar(), [v.HomogeneousArrayType(v.HomogeneousArrayType(v.AnyType())),v.SimplexType(),v.CountType(),v.CountType()], v.AnyType(), min_req_args=0))

# %%
f= ripl.assume("grammar","(scope_include (quote grammar) 0 (gp_grammar (array max_se max_lin max_per max_wn) structure_prior number_of_components global_part))")

# %% [markdown]
# #### way so that we can visualize posterior:

# %%
ripl.bind_foreign_sp("covfunc_interpreter",typed_nr(GrammarInterpreter(), [v.AnyType()], v.AnyType()))

# %%
ripl.assume("interp","(covfunc_interpreter grammar)")
# Out:
# 'LIN+WN'

# %%
#ripl.assume('covariance_function','(if (eq cov_index 0) wn (if (eq cov_index 1) lin (if (eq cov_index 2) se per)))' )

# %% [markdown]
# #### way without if:

# %%
'''
ripl.infer("""(let ((d (empty)))
   (do (repeat 1
        (do (sample  cov_index)
            (bind (collect cov_index) (curry into d))))
       (plotf (quote h0) d)
       ))""")
'''
# Out:
# '\nripl.infer("""(let ((d (empty)))\n   (do (repeat 1\n        (do (sample  cov_index)\n            (bind (collect cov_index) (curry into d))))\n       (plotf (quote h0) d)\n       ))""")\n'

# %% [markdown]
# ### Gaussian Process

# %%
ripl.bind_foreign_sp("make_gp_part_der",gp_with_derivatives.makeGPSP)

# %%
#ripl.assume('cov','(apply_function  func_times  per lin )')
ripl.assume('gp','(scope_include (quote parameter) 1 (make_gp_part_der zero grammar))')

# %% [markdown]
# ## Plot the Prior

# %%
def genSamples(x):
    sampleString='(gp (array '
    for i in range(len(x)):
        sampleString+= str(x[i]) + ' ' 
    sampleString+='))'
    #print(sampleString)
    return sampleString

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
for i in range(100):#
    xpost= np.random.uniform(low=0.0, high=10.0, size=50)
    sampleString=genSamples(xpost)
    ypost = ripl.sample(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)

pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()

# %%
def makeObservations(x,y):
    print(y)
    xString = genSamples(x)
    ripl.observe(xString, array(y.tolist()))
    #ripl.observe('(gp (array -3 4))', array([-1, 1]))
    
makeObservations(xtrain,ytrain)
# Out:
# [ 12.54059429  11.65104644  18.29747955  11.45015349   3.13545281
#   19.65541927  14.5693104    9.40182794  17.63724415  15.61487354]

# %%
#ripl.infer(100)

# %%
cycle=50
for i in range(cycle):
    ripl.infer("(hmc parameter all 10 10 3)")
    ripl.infer("(mh grammar one 1)") 
    ripl.infer("(mh structure one 1)")
    ripl.infer("(mh global one 1)")
    ripl.infer("(mh components all 1)")
    ripl.infer("(mh component_hyper one 1)")
    ripl.infer(2)

# %%
'''
cycle=50
for i in range(cycle):
    ripl.infer("(hmc parameter all 10 10 3)")
    ripl.infer(10)
'''
# Out:
# '\ncycle=50\nfor i in range(cycle):\n    ripl.infer("(hmc parameter all 10 10 3)")\n    ripl.infer(10)\n'

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)

for i in range(100):
    xpost= np.random.uniform(low=0.0, high=10.0, size=50)
    sampleString=genSamples(xpost)
    ypost = ripl.sample(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()

# %%
fig = plt.figure(figsize=(figlength,figheigth), dpi=200)
for i in range(100):
    xpost= np.random.uniform(low=0.0, high=10.0, size=10)
    sampleString=genSamples(xpost)
    ypost = ripl.predict(sampleString)
    yp = [y for (x,y) in sorted(zip(xpost,ypost))]
    pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
    
pl.plot(actual_x,actual_f,c="#3498db")
pl.scatter(xtrain,ytrain,c="black",marker="x",linewidth=2,s=60)
pl.xlim(xa,xb)
pl.ylim(ya,yb)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-8a59ae650266> in <module>()
#       3     xpost= np.random.uniform(low=0.0, high=10.0, size=10)
#       4     sampleString=genSamples(xpost)
# ----> 5     ypost = ripl.predict(sampleString)
#       6     yp = [y for (x,y) in sorted(zip(xpost,ypost))]
#       7     pl.plot(sorted(xpost),yp,c="red",alpha=0.1,linewidth=2)
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in predict(self, expression, label, type)
#     432             label = _symbolize(label)
#     433             i = {'instruction':'labeled_predict', 'expression':expression, 'label':label}
# --> 434         value = self.execute_instruction(i)['value']
#     435         return value if type else u.strip_types(value)
#     436
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params, suppress_pausing_continous_inference)
#     130                 stringable_instruction = instruction
#     131                 parsed_instruction = self._ensure_parsed(instruction)
# --> 132             ret_value = self.sivm.execute_instruction(parsed_instruction, suppress_pausing_continous_inference=suppress_pausing_continous_inference)
#     133         except VentureException as e:
#     134             import sys
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction, suppress_pausing_continous_inference)
#      68                 return f(instruction)
#      69             else:
# ---> 70                 response = self._call_core_sivm_instruction(instruction)
#      71                 return response
#      72
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     129             desugared_src_location['expression_index'] = new_index
#     130         try:
# --> 131             response = self.core_sivm.execute_instruction(desugared_instruction)
#     132         except VentureException as e:
#     133             # raise # One can suppress error annotation by uncommenting this
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      44         utils.validate_instruction(instruction,self._implemented_instructions)
#      45         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 46         return f(instruction)
#      47
#      48     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_predict(self, instruction)
#      98         exp = utils.validate_arg(instruction,'expression',
#      99                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# --> 100         did, val = self.engine.predict(exp)
#     101         return {"directive_id":did, "value":val}
#     102
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in predict(self, datum)
#      85
#      86   def predict(self, datum):
# ---> 87     (did, answers) = self.predict_all(datum)
#      88     return (did, answers[0])
#      89
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in predict_all(self, datum)
#      81   def predict_all(self,datum):
#      82     baseAddr = self.nextBaseAddr()
# ---> 83     values = self.model.evaluate(baseAddr, datum)
#      84     return (self.directiveCounter,values)
#      85
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/trace_set.pyc in evaluate(self, baseAddr, datum)
#      59
#      60   def evaluate(self, baseAddr, datum):
# ---> 61     return self.traces.map('evaluate', baseAddr, datum)
#      62
#      63   def observe(self, baseAddr, datum, val):
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in map(self, cmd, *args, **kwargs)
#     185     '''Delegate command to all workers'''
#     186     # send command
# --> 187     for pipe in self.pipes: pipe.send((cmd, args, kwargs, None))
#     188     if cmd == 'stop': return
#     189     res = []
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in send(self, obj)
#     516
#     517   def send(self, obj):
# --> 518     self.other.emplace(obj)
#     519
#     520   def emplace(self, obj):
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in emplace(self, obj)
#     521     self.objs.append(obj)
#     522     for cb in self.cbs:
# --> 523       cb()
#     524
#     525   def recv(self):
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in poll(self)
#     338       res = getattr(self.objs[index], cmd)(*args, **kwargs)
#     339     else:
# --> 340       res = [getattr(o, cmd)(*args, **kwargs) for o in self.objs]
#     341     self.pipe.send(res)
#     342
#
# /usr/local/lib/python2.7/dist-packages/venture/multiprocess.pyc in wrapped(*args, **kwargs)
#      90   def wrapped(*args, **kwargs):
#      91     try:
# ---> 92       res = f(*args, **kwargs)
#      93     except Exception:
#      94       # If I return the traceback object and try to format it
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/trace.pyc in evaluate(self, baseAddr, exp)
#      47   def evaluate(self, baseAddr, exp):
#      48     assert baseAddr not in self.directives
# ---> 49     self.trace.eval(baseAddr,exp)
#      50     self.directives[baseAddr] = ["evaluate", exp]
#      51     return self.trace.extractValue(baseAddr)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/trace.pyc in eval(self, id, exp)
#     352   def eval(self,id,exp):
#     353     assert not id in self.families
# --> 354     (_,self.families[id]) = evalFamily(self,Address(List(id)),self.unboxExpression(exp),self.globalEnv,Scaffold(),False,OmegaDB(),{})
#     355
#     356   def bindInGlobalEnv(self,sym,id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 171   weight += applyPSP(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     172   assert isinstance(weight, numbers.Number)
#     173   return weight
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in applyPSP(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199   else:
#     200     # if we simulate from the prior, the weight is 0
# --> 201     newValue = psp.simulate(args) if not shouldRestore else oldValue
#     202
#     203   trace.setValueAt(node,newValue)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/psp.pyc in simulate(self, args)
#     322
#     323   def simulate(self,args):
# --> 324     return self.f_type.wrap_return(self.psp.simulate(self.f_type.unwrap_args(args)))
#     325   def gradientOfSimulate(self, args, value, direction):
#     326     # TODO Should gradientOfSimulate unwrap the direction and wrap the
#
# /home/ulli/VentIPyN/SPs/gp_withDer.pyc in simulate(self, args)
#     122     samples = args.spaux
#     123     xs = args.operandValues[0]
# --> 124     return self.makeGP(samples).sample(*xs)
#     125
#     126   def logDensity(self,os,args):
#
# /home/ulli/VentIPyN/SPs/gp_withDer.pyc in sample(self, *xs)
#      71   def sample(self, *xs):
#      72     """Sample at a (set of) point(s)."""
# ---> 73     mu, sigma = self.getNormal(xs)
#      74     os = npr.multivariate_normal(mu.A1, sigma)
#      75     return os
#
# /home/ulli/VentIPyN/SPs/gp_withDer.pyc in getNormal(self, xs)
#      62
#      63         sigma22 = self.cov_matrix(x2s, x2s)
# ---> 64         inv22 = la.pinv(sigma22)
#      65         mu = mu1 +np.dot(sigma12,(np.dot(inv22, (a2 - mu2))))
#      66         sigma = sigma11 - np.dot(sigma12,np.dot(inv22,sigma21))
#
# /usr/lib/python2.7/dist-packages/numpy/linalg/linalg.pyc in pinv(a, rcond)
#    1592         else:
#    1593             s[i] = 0.;
# -> 1594     res = dot(transpose(vt), multiply(s[:, newaxis], transpose(u)))
#    1595     return wrap(res)
#    1596
#
# KeyboardInterrupt:

# %%
dataset=ripl.infer("(collect structure_prior )")
df =dataset.asPandas()

# %%
df['structure_prior']
# Out:
# 0    [0.00805331563894, 0.308185532348, 0.202251759...
# 1    [0.0888800588287, 0.388193703216, 0.0345603146...
# 2    [0.00694438356123, 0.923734685514, 0.016322106...
# 3    [0.00372972810252, 0.0910618708899, 0.02337082...
# 4    [0.00460300489078, 0.217136055546, 0.004242164...
# 5    [0.209277655337, 0.265328670568, 0.28278171470...
# 6    [0.000233120637173, 0.710437613624, 0.00164774...
# 7    [0.425650815842, 0.327365953709, 0.00998343139...
# 8    [0.305744778931, 0.584808174624, 0.02143197630...
# 9    [0.328293270833, 0.282779509754, 0.32318203421...
# Name: structure_prior, dtype: object

# %%
se=0
lin=0
per=0
wn=0
for i in range(len(df['structure_prior'])):
    row=np.array(df['structure_prior'][i])
    se+=row[0]
    lin+=row[1]
    per+=row[2]
    wn+=row[3]
print(se/i)
print(lin/i)
print(per/i)
print(wn/i)
# Out:
# 0.153490014733
# 0.455447974422
# 0.102197119027
# 0.399976002929

# %%
ripl.infer("""(let ((d (empty)))
   (do (repeat 1
        (do (sample  number_of_components)
            (bind (collect number_of_components ) (curry into d))))
       (plotf (quote (h0)) d)))""")
# Out:
# stat_bin: binwidth defaulted to range/30.
#     Use 'binwidth = x' to adjust this.
# ERROR:
# ---------------------------------------------------------------------------
# VentureException                          Traceback (most recent call last)
# <ipython-input-53-a61f02536f24> in <module>()
#       3         (do (sample  number_of_components)
#       4             (bind (collect number_of_components ) (curry into d))))
# ----> 5        (plotf (quote (h0)) d)))""")
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in infer(self, params, type, suppress_pausing_continous_inference)
#     593         # The suppress_pausing_continous_inference flag is used by the
#     594         # thread doing the continuous inference.
# --> 595         o = self.execute_instruction({'instruction':'infer', 'expression': self.defaultInferProgram(params)}, suppress_pausing_continous_inference=suppress_pausing_continous_inference)
#     596         value = o["value"]
#     597         return value if type else u.strip_types(value)
#
# /usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.pyc in execute_instruction(self, instruction, params, suppress_pausing_continous_inference)
#     130                 stringable_instruction = instruction
#     131                 parsed_instruction = self._ensure_parsed(instruction)
# --> 132             ret_value = self.sivm.execute_instruction(parsed_instruction, suppress_pausing_continous_inference=suppress_pausing_continous_inference)
#     133         except VentureException as e:
#     134             import sys
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in execute_instruction(self, instruction, suppress_pausing_continous_inference)
#      68                 return f(instruction)
#      69             else:
# ---> 70                 response = self._call_core_sivm_instruction(instruction)
#      71                 return response
#      72
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.pyc in _call_core_sivm_instruction(self, instruction)
#     129             desugared_src_location['expression_index'] = new_index
#     130         try:
# --> 131             response = self.core_sivm.execute_instruction(desugared_instruction)
#     132         except VentureException as e:
#     133             # raise # One can suppress error annotation by uncommenting this
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in execute_instruction(self, instruction)
#      44         utils.validate_instruction(instruction,self._implemented_instructions)
#      45         f = getattr(self,'_do_'+instruction['instruction'])
# ---> 46         return f(instruction)
#      47
#      48     ###############################
#
# /usr/local/lib/python2.7/dist-packages/venture/sivm/core_sivm.pyc in _do_infer(self, instruction)
#     151         e = utils.validate_arg(instruction,'expression',
#     152                 utils.validate_expression,modifier=_modify_expression, wrap_exception=False)
# --> 153         val = self.engine.infer(e)
#     154         return {"value":val}
#     155
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in infer(self, program)
#     187       with self.inference_trace():
#     188         with self.self_evaluating_scope_hack():
# --> 189           did = self._do_infer(program)
#     190           ans = self._extract_infer_result(did)
#     191           self.infer_trace.uneval(did) # TODO This becomes "forget" after the engine.Trace wrapper
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/engine.pyc in _do_infer(self, program)
#     198     self.directiveCounter += 1
#     199     did = self.directiveCounter # Might be mutated by reentrant execution
# --> 200     self.infer_trace.eval(did, [program, v.blob(Infer(self))])
#     201     return did
#     202
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/trace.pyc in eval(self, id, exp)
#     352   def eval(self,id,exp):
#     353     assert not id in self.families
# --> 354     (_,self.families[id]) = evalFamily(self,Address(List(id)),self.unboxExpression(exp),self.globalEnv,Scaffold(),False,OmegaDB(),{})
#     355
#     356   def bindInGlobalEnv(self,sym,id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     166 def apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients):
#     167   weight = applyPSP(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 168   weight += evalRequests(trace,requestNode,scaffold,shouldRestore,omegaDB,gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalRequests(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     226       else:
#     227         address = node.address.request(esr.addr)
# --> 228         (w,esrParent) = evalFamily(trace,address,esr.exp,esr.env,scaffold,shouldRestore,omegaDB,gradients)
#     229         weight += w
#     230       if trace.containsSPFamilyAt(node,esr.id):
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in evalFamily(trace, address, exp, env, scaffold, shouldRestore, omegaDB, gradients)
#     145     (requestNode,outputNode) = trace.createApplicationNodes(address,nodes[0],nodes[1:],env)
#     146     try:
# --> 147       weight += apply(trace,requestNode,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     148     except VentureNestedRiplMethodError as err:
#     149       # This is a hack to allow errors raised by inference SP actions
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in apply(trace, requestNode, outputNode, scaffold, shouldRestore, omegaDB, gradients)
#     169   assert len(trace.esrParentsAt(outputNode)) == len(trace.valueAt(requestNode).esrs)
#     170   weight += regenESRParents(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
# --> 171   weight += applyPSP(trace,outputNode,scaffold,shouldRestore,omegaDB,gradients)
#     172   assert isinstance(weight, numbers.Number)
#     173   return weight
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/regen.pyc in applyPSP(trace, node, scaffold, shouldRestore, omegaDB, gradients)
#     199   else:
#     200     # if we simulate from the prior, the weight is 0
# --> 201     newValue = psp.simulate(args) if not shouldRestore else oldValue
#     202
#     203   trace.setValueAt(node,newValue)
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/psp.pyc in simulate(self, args)
#     322
#     323   def simulate(self,args):
# --> 324     return self.f_type.wrap_return(self.psp.simulate(self.f_type.unwrap_args(args)))
#     325   def gradientOfSimulate(self, args, value, direction):
#     326     # TODO Should gradientOfSimulate unwrap the direction and wrap the
#
# /usr/local/lib/python2.7/dist-packages/venture/lite/inference_sps.pyc in simulate(self, args)
#      54     self.desc = desc
#      55   def simulate(self, args):
# ---> 56     ans = getattr(args.operandValues[0], self.name)(*self.operands)
#      57     return (ans, args.operandValues[0])
#      58   def description(self, _name):
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/inference.pyc in plotf(self, spec, dataset)
#     105   def plotf(self, spec, dataset):
#     106     spec = ExpressionType().asPython(spec)
# --> 107     PlotSpec(spec).plot(dataset.asPandas(), dataset.ind_names)
#     108   def plotf_to_file(self, basenames, spec, dataset):
#     109     filenames = ExpressionType().asPython(basenames)
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/plot_spec.pyc in plot(self, dataset, names, filenames)
#      63   def plot(self, dataset, names, filenames=None):
#      64     import matplotlib.pylab as plt
# ---> 65     figs = self.draw(dataset, names)
#      66     if filenames is None:
#      67       plt.show()
#
# /usr/local/lib/python2.7/dist-packages/venture/engine/plot_spec.pyc in draw(self, dataset, names)
#      58         obj = self._interp_scale(dim, scale)
#      59         if obj: plot += obj
# ---> 60       figs.append(self._add_date(plot.draw()))
#      61     return figs
#      62
#
# /usr/local/lib/python2.7/dist-packages/ggplot/ggplot.pyc in draw(self)
#     305
#     306                     data = self._make_plot_data(data, _aes)
# --> 307                     callbacks = geom.plot_layer(data, ax)
#     308                     if callbacks:
#     309                         for callback in callbacks:
#
# /usr/local/lib/python2.7/dist-packages/ggplot/geoms/geom.pyc in plot_layer(self, data, ax)
#     115         _cols = set(data.columns) & set(self.manual_aes)
#     116         data = data.drop(_cols, axis=1)
# --> 117         data = self._calculate_stats(data)
#     118         self._verify_aesthetics(data)
#     119         _needed = self.valid_aes | self._extra_requires
#
# /usr/local/lib/python2.7/dist-packages/ggplot/geoms/geom.pyc in _calculate_stats(self, data)
#     276                 new_data = new_data.append(_data, ignore_index=True)
#     277         else:
# --> 278             new_data = self._stat._calculate(data)
#     279
#     280         return new_data
#
# /usr/local/lib/python2.7/dist-packages/ggplot/stats/stat_bin.pyc in _calculate(self, data)
#     125                             })
#     126         _wfreq_table = pd.pivot_table(_df, values='weights',
# --> 127                                       rows=['assignments'], aggfunc=np.sum)
#     128
#     129         # For numerical x values, empty bins get have no value
#
# VentureException: *** evaluation: pivot_table() got an unexpected keyword argument 'rows'
# {'cause': TypeError("pivot_table() got an unexpected keyword argument 'rows'",), 'address': [[5032], [5026, 2, 1, 2, 1], [5026, 2, 1, 2, 1, 0, 2, 1]]}
# Caused by
# pivot_table() got an unexpected keyword argument 'rows'
# Trying to annotate an exception at SIVM level led to:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.py", line 137, in _call_core_sivm_instruction
#     e = self._annotate(e, instruction)
#   File "/usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.py", line 177, in _annotate
#     e.data['stack_trace'] = [frame for frame in [self._resugar(index) for index in address] if frame is not None]
#   File "/usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.py", line 216, in _resugar
#     exp, syntax = self._get_syntax_record(did)
#   File "/usr/local/lib/python2.7/dist-packages/venture/sivm/venture_sivm.py", line 203, in _get_syntax_record
#     self.syntax_dict[did] = self.attempted.pop()
# IndexError: pop from empty list
#
# Trying to annotate an exception led to:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.py", line 137, in execute_instruction
#     annotated = self._annotated_error(e, instruction)
#   File "/usr/local/lib/python2.7/dist-packages/venture/ripl/ripl.py", line 156, in _annotated_error
#     for i, frame in enumerate(e.data['stack_trace']):
# KeyError: 'stack_trace'
# An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 31))

# %%
ripl.infer("""(let ((d (empty)))
   (do (repeat 1
        (do (sample  global_part)
            (bind (collect global_part ) (curry into d))))
       (plotf (quote (h0)) d)))""")

# %%
ripl.infer("""(let ((d (empty)))
   (do (repeat 1
        (do (sample  interp)
            (bind (collect interp ) (curry into d))))
       (plotf (quote (h0)) d)))""")

# %%
dataset=ripl.infer("(collect interp )")
df =dataset.asPandas()
dict_kernels={}
for i in range(len(df['interp'])):
    if df['interp'][i] in dict_kernels:
        dict_kernels[df['interp'][i]]+=1
    else:
        dict_kernels[df['interp'][i]]=1
dict_kernels

# %%
ripl.infer("""(let ((d (empty)))
   (do (repeat 1
        (do (sample  interp)
            (bind (collect interp ) (curry into d))))
       (printf d)))""")

# %%
end = timeit.timeit()
print end - start
